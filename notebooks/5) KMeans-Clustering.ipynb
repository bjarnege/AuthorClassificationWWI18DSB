# %%
import pandas as pd
from sklearn.cluster import KMeans
from Transformation import StackedTransformation, transformation

# %%
# read the whole dataset
df_full_preprocessed = pd.read_pickle("./df_full_preprocessed.pkl")

# %% [markdown]
# # K-Means

# %%
class BuildClusteringPipeline:
    
    def __init__(self, df, k_text, k_numerical, random_id=42):
        self.df = df
        self.k_text = k_text
        self.k_numerical = k_numerical
        self.random_id = random_id
        
    def build_datasets(self):

# %%
df_full_preprocessed
# Out:
#        gender  age              topic      sign  Text length  Number URLs  \
# 0        male   15            Student       Leo          157            0
# 1        male   15            Student       Leo          181            3
# 2        male   15            Student       Leo        25467            2
# 3        male   33  InvestmentBanking  Aquarius          402            2
# 4        male   33  InvestmentBanking  Aquarius         3695            4
# ...       ...  ...                ...       ...          ...          ...
# 616074   male   23            Student    Taurus          257            0
# 616075   male   23            Student    Taurus          393            0
# 616076   male   23            Student    Taurus           87            0
# 616077   male   23            Student    Taurus          343            0
# 616078   male   23            Student    Taurus         1269            0
#
#         Number mails  Uppercase ratio  Lowercase ratio  Number ratio  ...  \
# ...
